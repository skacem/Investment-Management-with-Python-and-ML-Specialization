# %% [markdown]
# # Liability-Driven Investing
#
# ![image.png](attachment:bb275780-fb1b-474c-af0a-1692bf0ef162.png)

# %% [markdown]
# * Liability-Driven investing strategies involve a split between PSP and LHP
# * The Allocation between the safe and risky portfolio is a function of the investor's bollar and risk budget (Conflict)
#
# # Beyond LDI
